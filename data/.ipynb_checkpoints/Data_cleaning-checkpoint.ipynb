# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import kagglehub
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

from sklearn.preprocessing import RobustScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 from sklearn.model_selection import train_test_split
#       7 from sklearn.linear_model import LinearRegression
# ----> 8 import kagglehub
#       9 from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#      10 import numpy as np
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
df = pd.read_csv('Alarms_of_the_sensors.csv', sep=None, engine='python')

# %%
df.head()

# %%
df = df.drop(columns=['Assignee'], errors='ignore')

# %%
# print(df.columns.tolist())
columns_to_show = ['Timestamp', 'sensor_id', 'alarm_type', 'severity', 'status']
existing_columns = [col for col in columns_to_show if col in df.columns]
print(df[existing_columns].head())
# Out:
#              Timestamp    sensor_id         alarm_type     severity  \
# 0  2025-11-10 16:19:48  Sensor_0057        Уровень CO2  Критический
# 1  2025-11-09 05:38:38  Sensor_0013  Потеря соединения  Критический
# 2  2025-11-09 05:38:38  Sensor_0089  Потеря соединения  Критический
# 3  2025-11-09 05:38:38  Sensor_0079  Потеря соединения  Критический
# 4  2025-11-09 05:38:38  Sensor_0068  Потеря соединения  Критический
#
#                         status
# 0  Сброшенные неподтвержденные
# 1  Сброшенные неподтвержденные
# 2  Сброшенные неподтвержденные
# 3  Сброшенные неподтвержденные
# 4  Сброшенные неподтвержденные

# %%
df['alarm_type'].unique()
# Out:
# array(['Уровень CO2', 'Потеря соединения', 'Курение',
#        'Высокая концентрация CO2', 'Высокая температура',
#        'Низкая влажность'], dtype=object)

# %%
df['severity'].unique()
# Out:
# array(['Критический'], dtype=object)

# %%
df['sensor_id'] = df['sensor_id'].str.strip()

# %%
# from datetime import timedelta

# alarm_time = alarms.loc[alarms['sensor_id'] == sensor_id, 'timestamp'].iloc[0]
# window_start = alarm_time - timedelta(minutes=5)
# window_end = alarm_time + timedelta(minutes=5)

# sensor_window = sensor_df[(sensor_df['Timestamp'] >= window_start) & 
#                           (sensor_df['Timestamp'] <= window_end)]

# %%
alarms = pd.read_csv('Alarms_of_the_sensors.csv', sep=None, engine='python')

# %%
sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')
sensor_alarms['timestamp'] = pd.to_datetime(sensor_alarms['timestamp'], errors='coerce')

# %%
sensor_df = sensor_df.sort_values('Timestamp')
sensor_alarms = sensor_alarms.sort_values('timestamp')

# %%
# Ensure both have proper datetime
sensor_df['Timestamp'] = pd.to_datetime(sensor_df['Timestamp'], errors='coerce')
sensor_alarms['Timestamp'] = pd.to_datetime(sensor_alarms['Timestamp'], errors='coerce')

# Sort both before merge_asof (required!)
sensor_df = sensor_df.sort_values('Timestamp')
sensor_alarms = sensor_alarms.sort_values('Timestamp')

# Merge by nearest timestamp before alarm
merged_df = pd.merge_asof(
    sensor_df,
    sensor_alarms[['Timestamp', 'alarm_type', 'severity', 'status']],
    on='Timestamp',
    direction='backward'
)

# %%
df['Timestamp', 'sensor_id', 'alarm_type', 'severity', 'status'].head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Timestamp', 'sensor_id', 'alarm_type', 'severity', 'status'].head(10)
#
# NameError: name 'df' is not defined
